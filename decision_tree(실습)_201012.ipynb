# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rc('axes', unicode_minus = False)

# %%
df = pd.read_csv('./data/IRIS.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df['id'] = range(len(df))

df.head()

df = df[['id','sepal_length','sepal_width','petal_length','petal_width','species']]

df.head()

train = df.sample(100, replace = False, random_state = 2020)

train = train.reset_index().drop('index', axis = 1)

test = df.loc[~df['id'].isin(train['id'])]

test = test.reset_index().drop('index', axis = 1)

# %%
train
# Out:
#      id  sepal_length  sepal_width  petal_length  petal_width          species
# 0   104           6.5          3.0           5.8          2.2   Iris-virginica
# 1     8           4.4          2.9           1.4          0.2      Iris-setosa
# 2    61           5.9          3.0           4.2          1.5  Iris-versicolor
# 3    54           6.5          2.8           4.6          1.5  Iris-versicolor
# 4    78           6.0          2.9           4.5          1.5  Iris-versicolor
# ..  ...           ...          ...           ...          ...              ...
# 95  149           5.9          3.0           5.1          1.8   Iris-virginica
# 96   14           5.8          4.0           1.2          0.2      Iris-setosa
# 97  145           6.7          3.0           5.2          2.3   Iris-virginica
# 98   94           5.6          2.7           4.2          1.3  Iris-versicolor
# 99   72           6.3          2.5           4.9          1.5  Iris-versicolor
#
# [100 rows x 6 columns]

# %%
test
# Out:
#      id  sepal_length  sepal_width  petal_length  petal_width          species
# 0     1           4.9          3.0           1.4          0.2      Iris-setosa
# 1     3           4.6          3.1           1.5          0.2      Iris-setosa
# 2     6           4.6          3.4           1.4          0.3      Iris-setosa
# 3     9           4.9          3.1           1.5          0.1      Iris-setosa
# 4    20           5.4          3.4           1.7          0.2      Iris-setosa
# 5    21           5.1          3.7           1.5          0.4      Iris-setosa
# 6    22           4.6          3.6           1.0          0.2      Iris-setosa
# 7    29           4.7          3.2           1.6          0.2      Iris-setosa
# 8    33           5.5          4.2           1.4          0.2      Iris-setosa
# 9    38           4.4          3.0           1.3          0.2      Iris-setosa
# 10   42           4.4          3.2           1.3          0.2      Iris-setosa
# 11   48           5.3          3.7           1.5          0.2      Iris-setosa
# 12   52           6.9          3.1           4.9          1.5  Iris-versicolor
# 13   55           5.7          2.8           4.5          1.3  Iris-versicolor
# 14   62           6.0          2.2           4.0          1.0  Iris-versicolor
# 15   63           6.1          2.9           4.7          1.4  Iris-versicolor
# 16   65           6.7          3.1           4.4          1.4  Iris-versicolor
# 17   66           5.6          3.0           4.5          1.5  Iris-versicolor
# 18   67           5.8          2.7           4.1          1.0  Iris-versicolor
# 19   68           6.2          2.2           4.5          1.5  Iris-versicolor
# 20   69           5.6          2.5           3.9          1.1  Iris-versicolor
# 21   71           6.1          2.8           4.0          1.3  Iris-versicolor
# 22   73           6.1          2.8           4.7          1.2  Iris-versicolor
# 23   79           5.7          2.6           3.5          1.0  Iris-versicolor
# 24   80           5.5          2.4           3.8          1.1  Iris-versicolor
# 25   82           5.8          2.7           3.9          1.2  Iris-versicolor
# 26   83           6.0          2.7           5.1          1.6  Iris-versicolor
# 27   90           5.5          2.6           4.4          1.2  Iris-versicolor
# 28   91           6.1          3.0           4.6          1.4  Iris-versicolor
# 29   96           5.7          2.9           4.2          1.3  Iris-versicolor
# 30   98           5.1          2.5           3.0          1.1  Iris-versicolor
# 31  100           6.3          3.3           6.0          2.5   Iris-virginica
# 32  102           7.1          3.0           5.9          2.1   Iris-virginica
# 33  107           7.3          2.9           6.3          1.8   Iris-virginica
# 34  110           6.5          3.2           5.1          2.0   Iris-virginica
# 35  112           6.8          3.0           5.5          2.1   Iris-virginica
# 36  114           5.8          2.8           5.1          2.4   Iris-virginica
# 37  118           7.7          2.6           6.9          2.3   Iris-virginica
# 38  124           6.7          3.3           5.7          2.1   Iris-virginica
# 39  125           7.2          3.2           6.0          1.8   Iris-virginica
# 40  127           6.1          3.0           4.9          1.8   Iris-virginica
# 41  129           7.2          3.0           5.8          1.6   Iris-virginica
# 42  131           7.9          3.8           6.4          2.0   Iris-virginica
# 43  133           6.3          2.8           5.1          1.5   Iris-virginica
# 44  135           7.7          3.0           6.1          2.3   Iris-virginica
# 45  136           6.3          3.4           5.6          2.4   Iris-virginica
# 46  138           6.0          3.0           4.8          1.8   Iris-virginica
# 47  139           6.9          3.1           5.4          2.1   Iris-virginica
# 48  140           6.7          3.1           5.6          2.4   Iris-virginica
# 49  141           6.9          3.1           5.1          2.3   Iris-virginica

# %%
from sklearn.tree import DecisionTreeClassifier
DecisionTreeClassifier
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(min_samples_split = 10)

# %%
model.fit(train[['sepal_length','sepal_width','petal_length','petal_width']], train['species'])
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
pred = model.predict(test[['sepal_length','sepal_width','petal_length','petal_width']])

# %%
test['pred'] = pred

# %%
(test['species'] == test['pred']).mean()
# Out:
# 0.96

# %%
from sklearn import tree

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 16,10

# %%
a = tree.plot_tree(model, feature_names = ['sepal_length','sepal_width','petal_length','petal_width'], 
                  fontsize = 10, max_depth = 8)
plt.show(a)
