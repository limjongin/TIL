# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {'a' : [4,5,6],
    'b' : [7,8,9],
    'c' : [10,11,12]},
    index = [1,2,3])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df['a']
# Out:
# 1    4
# 2    5
# 3    6
# Name: a, dtype: int64

# %%
df['b']
# Out:
# 1    7
# 2    8
# 3    9
# Name: b, dtype: int64

# %%
df['c']
# Out:
# 1    10
# 2    11
# 3    12
# Name: c, dtype: int64

# %%
df[['a','b']]
# Out:
#    a  b
# 1  4  7
# 2  5  8
# 3  6  9

# %%
df.loc[1]
# Out:
# a     4
# b     7
# c    10
# Name: 1, dtype: int64

# %%
df.loc[3]
# Out:
# a     6
# b     9
# c    12
# Name: 3, dtype: int64

# %%
df.loc[3,'a']
# Out:
# 6

# %%
df.loc[[1,2,],['a','b']]
# Out:
#    a  b
# 1  4  7
# 2  5  8

# %%
df=pd.DataFrame(
[[4,7,10],
[5,8,11],
[6,9,12]],
index = [1,2,3],
columns = ['a','b','c'])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df = pd.DataFrame(
    {'a' : [4,5,6,6, np.nan],
    'b' : [7,8, np.nan, 9,9],
    'c' : [10,11,12, np.nan, 12]},
    index = pd.MultiIndex.from_tuples(
    [('d', 1),('d',2),('e',2),('e',3),('e',4)],
    names = ['n','v']))
df
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0
#   3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df[df['c'] >= 7]
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0
#   4  NaN  9.0  12.0

# %%
df
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0
#   3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df = df.drop_duplicates(keep = 'last')

# %%
df
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0
#   3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df[df['b'] != 7]
# Out:
#        a    b     c
# n v
# d 2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0
#   3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df['a'].isin([5])
# Out:
# n  v
# d  1    False
#    2     True
# e  2    False
#    3    False
#    4    False
# Name: a, dtype: bool

# %%
pd.isnull(df)
# Out:
#          a      b      c
# n v
# d 1  False  False  False
#   2  False  False  False
# e 2  False   True  False
#   3  False  False   True
#   4   True  False  False

# %%
df['a'].isnull().sum()
# Out:
# 1

# %%
pd.notnull(df)
# Out:
#          a      b      c
# n v
# d 1   True   True   True
#   2   True   True   True
# e 2   True  False   True
#   3   True   True  False
#   4  False   True   True

# %%
df.notnull().sum()
# Out:
# a    4
# b    4
# c    4
# dtype: int64

# %%
df.a.notnull()
# Out:
# n  v
# d  1     True
#    2     True
# e  2     True
#    3     True
#    4    False
# Name: a, dtype: bool

# %%
~df.a.notnull()
# Out:
# n  v
# d  1    False
#    2    False
# e  2    False
#    3    False
#    4     True
# Name: a, dtype: bool

# %%
df[df.b == 7] |df[df.a == 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# TypeError: unsupported operand type(s) for |: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-c424e8070a1f> in <module>
# ----> 1 df[df.b == 7] |df[df.a == 5]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     701
#     702             left, right = self.align(other, join="outer", level=level, copy=False)
# --> 703             new_data = left._combine_frame(right, pass_op, fill_value)
#     704             return left._construct_result(new_data)
#     705
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _combine_frame(self, other, func, fill_value, level)
#    5298         if ops.should_series_dispatch(self, other, func):
#    5299             # iterate over columns
# -> 5300             new_data = ops.dispatch_to_series(self, other, _arith_op)
#    5301         else:
#    5302             with np.errstate(all="ignore"):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     414         raise NotImplementedError(right)
#     415
# --> 416     new_data = expressions.evaluate(column_op, str_rep, left, right)
#     417     return new_data
#     418
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     206     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#     210
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#     123     return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in column_op(a, b)
#     383
#     384         def column_op(a, b):
# --> 385             return {i: func(a.iloc[:, i], b.iloc[:, i]) for i in range(len(a.columns))}
#     386
#     387     elif isinstance(right, ABCSeries) and axis == "columns":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in <dictcomp>(.0)
#     383
#     384         def column_op(a, b):
# --> 385             return {i: func(a.iloc[:, i], b.iloc[:, i]) for i in range(len(a.columns))}
#     386
#     387     elif isinstance(right, ABCSeries) and axis == "columns":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     547         rvalues = extract_array(other, extract_numpy=True)
#     548
# --> 549         res_values = logical_op(lvalues, rvalues, op)
#     550         return _construct_result(self, res_values, index=self.index, name=res_name)
#     551
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in logical_op(left, right, op)
#     364         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
#     365
# --> 366         res_values = na_logical_op(lvalues, rvalues, op)
#     367         res_values = filler(res_values)  # type: ignore
#     368
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     279             x = ensure_object(x)
#     280             y = ensure_object(y)
# --> 281             result = libops.vec_binop(x, y, op)
#     282         else:
#     283             # let null fall thru
#
# pandas/_libs/ops.pyx in pandas._libs.ops.vec_binop()
#
# pandas/_libs/ops.pyx in pandas._libs.ops.vec_binop()
#
# TypeError: unsupported operand type(s) for |: 'float' and 'bool'

# %%
df.head()
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0
#   3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df.tail()
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0
#   3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df.tail(2)
# Out:
#        a    b     c
# n v
# e 3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df.head(2)
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0

# %%
df.sample(n = 2)
# Out:
#        a    b     c
# n v
# e 4  NaN  9.0  12.0
# d 2  5.0  8.0  11.0

# %%
df.iloc[-2:]
# Out:
#        a    b     c
# n v
# e 3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df = pd.DataFrame({'population': [59000000, 65000000, 434000,
                                   434000, 434000, 337000, 11300,
                                   11300, 11300],
                    'GDP': [1937894, 2583560 , 12011, 4520, 12128,
                            17036, 182, 38, 311],
                    'alpha-2': ["IT", "FR", "MT", "MV", "BN",
                                "IS", "NR", "TV", "AI"]},
                   index=["Italy", "France", "Malta",
                          "Maldives", "Brunei", "Iceland",
                          "Nauru", "Tuvalu", "Anguilla"])

df.nlargest(3,'GDP')
# Out:
#          population      GDP alpha-2
# France     65000000  2583560      FR
# Italy      59000000  1937894      IT
# Iceland      337000    17036      IS

# %%
df.nsmallest(3, 'GDP')
# Out:
#           population  GDP alpha-2
# Tuvalu         11300   38      TV
# Nauru          11300  182      NR
# Anguilla       11300  311      AI

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
columns = ['sepal_width','sepal_length','species']
df[['sepal_width','sepal_length']]
# Out:
#      sepal_width  sepal_length
# 0            3.5           5.1
# 1            3.0           4.9
# 2            3.2           4.7
# 3            3.1           4.6
# 4            3.6           5.0
# ..           ...           ...
# 145          3.0           6.7
# 146          2.5           6.3
# 147          3.0           6.5
# 148          3.4           6.2
# 149          3.0           5.9
#
# [150 rows x 2 columns]

# %%
df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df.filter(regex = '^(?!species$).*')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.loc[2:5, 'sepal_width' : 'petal_width']
# Out:
#    sepal_width  petal_length  petal_width
# 2          3.2           1.3          0.2
# 3          3.1           1.5          0.2
# 4          3.6           1.4          0.2
# 5          3.9           1.7          0.4

# %%
df.iloc[:,[1,2,4]]
# Out:
#      sepal_width  petal_length    species
# 0            3.5           1.4     setosa
# 1            3.0           1.4     setosa
# 2            3.2           1.3     setosa
# 3            3.1           1.5     setosa
# 4            3.6           1.4     setosa
# ..           ...           ...        ...
# 145          3.0           5.2  virginica
# 146          2.5           5.0  virginica
# 147          3.0           5.2  virginica
# 148          3.4           5.4  virginica
# 149          3.0           5.1  virginica
#
# [150 rows x 3 columns]

# %%
df.iloc[2:5:,[1,3]]
# Out:
#    sepal_width  petal_width
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
df.loc[df['sepal_length'] > 5, ['sepal_length','sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 5             5.4          3.9
# 10            5.4          3.7
# 14            5.8          4.0
# 15            5.7          4.4
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [118 rows x 2 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
len(df)
# Out:
# 150

# %%
df.shape[0]
# Out:
# 150

# %%
df['species'].nunique()
# Out:
# 3

# %%
df.describe(include=(np.object))
# Out:
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %%
df.describe(include=(np.number))
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['petal_width'].sum()
# Out:
# 179.90000000000003

# %%
df['petal_width'].count()
# Out:
# 150

# %%
df['petal_width'].median()
# Out:
# 1.3

# %%
df['petal_width'].mean()
# Out:
# 1.199333333333334

# %%
df['petal_width'].quantile([0.25,0.75])
# Out:
# 0.25    0.3
# 0.75    1.8
# Name: petal_width, dtype: float64

# %%
df.min()
# Out:
# sepal_length       4.3
# sepal_width          2
# petal_length         1
# petal_width        0.1
# species         setosa
# dtype: object

# %%
df.max()
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %%
df.var()
# Out:
# sepal_length    0.685694
# sepal_width     0.189979
# petal_length    3.116278
# petal_width     0.581006
# dtype: float64

# %%
df.std()
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %%
def smp(x) :
    x = x[-3:]
    return x

# %%
df['species_3'] = df['species'].apply(lambda x : x[:3])

# %%
df['species-3'] = df['species'].apply(smp)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     species_3 species-3
# 0         set       osa
# 1         set       osa
# 2         set       osa
# 3         set       osa
# 4         set       osa
# ..        ...       ...
# 145       vir       ica
# 146       vir       ica
# 147       vir       ica
# 148       vir       ica
# 149       vir       ica
#
# [150 rows x 7 columns]

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                        "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                        "born": [np.nan, pd.Timestamp("1940-04-25"),
                                 np.nan]})
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(axis = 1, how = 'all')
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.fillna(0)
# Out:
#        name        toy                 born
# 0    Alfred          0                    0
# 1    Batman  Batmobile  1940-04-25 00:00:00
# 2  Catwoman   Bullwhip                    0

# %%
df = pd.DataFrame({'temp_c': [17.0, 25.0]},
                 index=['Portland', 'Berkeley'])
df
# Out:
#           temp_c
# Portland    17.0
# Berkeley    25.0

# %%
(temp_f=df['temp_c'] * 9 / 5 + 32)
df
# Out:
#   File "<ipython-input-129-706040d5689b>", line 1
#     (temp_f=df['temp_c'] * 9 / 5 + 32)
#            ^
# SyntaxError: invalid syntax

# %%
pd.qcut(df['temp_c'], 3, labels=["good", "medium", "bad"])
# Out:
# Portland    good
# Berkeley     bad
# Name: temp_c, dtype: category
# Categories (3, object): [good < medium < bad]

# %%
df.max(axis = 1)
# Out:
# Portland    17.0
# Berkeley    25.0
# dtype: float64

# %%
df.max(axis = 0)
# Out:
# temp_c    25.0
# dtype: float64

# %%
df.min(axis = 1)
# Out:
# Portland    17.0
# Berkeley    25.0
# dtype: float64

# %%
df.min(axis = 0)
# Out:
# temp_c    17.0
# dtype: float64

# %%
df = sns.load_dataset("mpg")
df.shape
# Out:
# (398, 9)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.sort_values('mpg').head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
#
#      model_year origin              name
# 28           70    usa          hi 1200d
# 25           70    usa         ford f250
# 26           70    usa         chevy c20
# 103          73    usa  chevrolet impala
# 124          73    usa  oldsmobile omega

# %%
df.sort_values('mpg', ascending = False).head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# 329          80   japan   honda civic 1500 gl
# 325          80  europe  vw rabbit c (diesel)
# 394          82  europe             vw pickup
# 326          80  europe    vw dasher (diesel)

# %%
df = df.rename(columns = {'model_year':'year'})

# %%
df.sort_index()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0        86.0    2790          15.6    82
# 394  44.0          4          97.0        52.0    2130          24.6    82
# 395  32.0          4         135.0        84.0    2295          11.6    82
# 396  28.0          4         120.0        79.0    2625          18.6    82
# 397  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# 0       usa  chevrolet chevelle malibu
# 1       usa          buick skylark 320
# 2       usa         plymouth satellite
# 3       usa              amc rebel sst
# 4       usa                ford torino
# ..      ...                        ...
# 393     usa            ford mustang gl
# 394  europe                  vw pickup
# 395     usa              dodge rampage
# 396     usa                ford ranger
# 397     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.reset_index()
# Out:
#      index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0        0  18.0          8         307.0       130.0    3504          12.0
# 1        1  15.0          8         350.0       165.0    3693          11.5
# 2        2  18.0          8         318.0       150.0    3436          11.0
# 3        3  16.0          8         304.0       150.0    3433          12.0
# 4        4  17.0          8         302.0       140.0    3449          10.5
# ..     ...   ...        ...           ...         ...     ...           ...
# 393    393  27.0          4         140.0        86.0    2790          15.6
# 394    394  44.0          4          97.0        52.0    2130          24.6
# 395    395  32.0          4         135.0        84.0    2295          11.6
# 396    396  28.0          4         120.0        79.0    2625          18.6
# 397    397  31.0          4         119.0        82.0    2720          19.4
#
#      year  origin                       name
# 0      70     usa  chevrolet chevelle malibu
# 1      70     usa          buick skylark 320
# 2      70     usa         plymouth satellite
# 3      70     usa              amc rebel sst
# 4      70     usa                ford torino
# ..    ...     ...                        ...
# 393    82     usa            ford mustang gl
# 394    82  europe                  vw pickup
# 395    82     usa              dodge rampage
# 396    82     usa                ford ranger
# 397    82     usa                 chevy s-10
#
# [398 rows x 10 columns]

# %%
df = df.drop(columns = ['mpg','year','name'])

# %%
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  origin
# 0            8         307.0       130.0    3504          12.0     usa
# 1            8         350.0       165.0    3693          11.5     usa
# 2            8         318.0       150.0    3436          11.0     usa
# 3            8         304.0       150.0    3433          12.0     usa
# 4            8         302.0       140.0    3449          10.5     usa
# ..         ...           ...         ...     ...           ...     ...
# 393          4         140.0        86.0    2790          15.6     usa
# 394          4          97.0        52.0    2130          24.6  europe
# 395          4         135.0        84.0    2295          11.6     usa
# 396          4         120.0        79.0    2625          18.6     usa
# 397          4         119.0        82.0    2720          19.4     usa
#
# [398 rows x 6 columns]

# %%
pd.melt?

# %%
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                    'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})

# %%
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, value_vars = ['A','B','C']).rename(columns={
    'variable' : 'var',
    'value' : 'val'
})
# Out:
#   var val
# 0   A   a
# 1   A   b
# 2   A   c
# 3   B   1
# 4   B   3
# 5   B   5
# 6   C   2
# 7   C   4
# 8   C   6

# %%
df.pivot?

# %%
df2 = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                               'two'],
                     'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                      'baz': [1, 2, 3, 4, 5, 6],
                       'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df2
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df3 = df2.pivot(index = 'foo', columns = 'bar', values = 'baz')
df3
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.melt?

# %%
df3.melt(id_vars=['foo'], value_vars=['A','B', 'C'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-152-15105b14d2ac> in <module>
# ----> 1 df3.melt(id_vars=['foo'], value_vars=['A','B', 'C'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level)
#    6504             var_name=var_name,
#    6505             value_name=value_name,
# -> 6506             col_level=col_level,
#    6507         )
#    6508
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#      54                     "The following 'id_vars' are not present "
#      55                     "in the DataFrame: {missing}"
# ---> 56                     "".format(missing=list(missing))
#      57                 )
#      58     else:
#
# KeyError: "The following 'id_vars' are not present in the DataFrame: ['foo']"

# %%
df3
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
pd.concat?

# %%
s1 = pd.Series(['a', 'b'])
s2 = pd.Series(['c', 'd'])

# %%
s2
# Out:
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1,s2], ignore_index = True)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
pd.concat([s1,s2], keys = ['s1','s2',], names = ['Series name','Row ID'])
# Out:
# Series name  Row ID
# s1           0         a
#              1         b
# s2           0         c
#              1         d
# dtype: object

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])

# %%
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])

# %%
pd.concat([df1, df2])
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                    columns=['letter', 'number', 'animal'])

# %%
pd.concat([df1,df3])
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1,df3], join = 'inner')
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df4 = pd.DataFrame([['bird', 'polly'], ['monkey', 'george']],
                   columns=['animal', 'name'])
df4
# Out:
#    animal    name
# 0    bird   polly
# 1  monkey  george

# %%
df5 = pd.DataFrame([1], index=['a'])
df6 = pd.DataFrame([2], index=['a'])

# %%
pd.concat([df5,df6], verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-e6e5037ffbf3> in <module>
# ----> 1 pd.concat([df5,df6], verify_integrity=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     450         self.copy = copy
#     451
# --> 452         self.new_axes = self._get_new_axes()
#     453
#     454     def get_result(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     515         return [
#     516             self._get_concat_axis() if i == self.axis else self._get_comb_axis(i)
# --> 517             for i in range(ndim)
#     518         ]
#     519
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     515         return [
#     516             self._get_concat_axis() if i == self.axis else self._get_comb_axis(i)
# --> 517             for i in range(ndim)
#     518         ]
#     519
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     570             )
#     571
# --> 572         self._maybe_check_integrity(concat_axis)
#     573
#     574         return concat_axis
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _maybe_check_integrity(self, concat_index)
#     580                 raise ValueError(
#     581                     "Indexes have overlapping values: "
# --> 582                     "{overlap!s}".format(overlap=overlap)
#     583                 )
#     584
#
# ValueError: Indexes have overlapping values: Index(['a'], dtype='object')

# %%
adf = pd.DataFrame({"x1":['A','B','C'],"x2":[1,2,3]})
adf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
bdf = pd.DataFrame({'x1':['A','B','D'], 'x3':['T','F','T']})
bdf
# Out:
#   x1 x3
# 0  A  T
# 1  B  F
# 2  D  T

# %%
pd.merge(adf, bdf, how = 'left', on = 'x1')
# Out:
#   x1  x2   x3
# 0  A   1    T
# 1  B   2    F
# 2  C   3  NaN

# %%
pd.merge(adf, bdf, how = 'right', on = 'x1')
# Out:
#   x1   x2 x3
# 0  A  1.0  T
# 1  B  2.0  F
# 2  D  NaN  T

# %%
pd.merge(adf, bdf, how = 'inner', on = 'x1')
# Out:
#   x1  x2 x3
# 0  A   1  T
# 1  B   2  F

# %%
pd.merge(adf, bdf, how = 'outer', on = 'x1')
# Out:
#   x1   x2   x3
# 0  A  1.0    T
# 1  B  2.0    F
# 2  C  3.0  NaN
# 3  D  NaN    T

# %%
pd.merge?

# %%
bdf.x1
# Out:
# 0    A
# 1    B
# 2    D
# Name: x1, dtype: object

# %%
adf.x1.isin(bdf.x1)
# Out:
# 0     True
# 1     True
# 2    False
# Name: x1, dtype: bool

# %%
adf[adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 0  A   1
# 1  B   2

# %%
adf[~adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 2  C   3

# %%
ydf = pd.DataFrame({'x1':['A','B','C'], 'x2' : [1,2,3]})
ydf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
zdf = pd.DataFrame({'x1':['B','C','D'], 'x2' : [2,3,4]})
zdf
# Out:
#   x1  x2
# 0  B   2
# 1  C   3
# 2  D   4

# %%
pd.merge(ydf, zdf)
# Out:
#   x1  x2
# 0  B   2
# 1  C   3

# %%
pd.merge(ydf, zdf, how = 'outer')
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3
# 3  D   4

# %%
pd.merge(ydf, zdf, how = 'outer', indicator = True).query('_merge == "left_only"').drop(columns = ['_merge'])
# Out:
#   x1  x2
# 0  A   1

# %%
df = sns.load_dataset('mpg')
df.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
df.groupby(by = 'origin')['cylinders'].size()
# Out:
# origin
# europe     70
# japan      79
# usa       249
# Name: cylinders, dtype: int64

# %%
df['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
pd.DataFrame(df.groupby(['model_year','origin'])['cylinders'].mean())
# Out:
#                    cylinders
# model_year origin
# 70         europe   4.000000
#            japan    4.000000
#            usa      7.636364
# 71         europe   4.000000
#            japan    4.000000
#            usa      6.200000
# 72         europe   4.000000
#            japan    3.800000
#            usa      6.888889
# 73         europe   4.000000
#            japan    4.250000
#            usa      7.241379
# 74         europe   4.000000
#            japan    4.000000
#            usa      6.266667
# 75         europe   4.000000
#            japan    4.000000
#            usa      6.400000
# 76         europe   4.250000
#            japan    4.500000
#            usa      6.363636
# 77         europe   4.000000
#            japan    4.166667
#            usa      6.222222
# 78         europe   4.833333
#            japan    4.000000
#            usa      6.000000
# 79         europe   4.250000
#            japan    4.000000
#            usa      6.260870
# 80         europe   4.111111
#            japan    4.076923
#            usa      4.285714
# 81         europe   4.500000
#            japan    4.333333
#            usa      4.923077
# 82         europe   4.000000
#            japan    4.000000
#            usa      4.300000

# %%
df2 = pd.DataFrame([[4,7,10],
                   [5,8,11],
                   [6,9,12]],
                   index = [1,2,3],
                   columns = ['a','b','c'])

# %%
df2
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df2.shift(1)
# Out:
#      a    b     c
# 1  NaN  NaN   NaN
# 2  4.0  7.0  10.0
# 3  5.0  8.0  11.0

# %%
df2['b'].shift(2)
# Out:
# 1    NaN
# 2    NaN
# 3    7.0
# Name: b, dtype: float64

# %%
df['model_year'].rank(method = 'dense')
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 393    13.0
# 394    13.0
# 395    13.0
# 396    13.0
# 397    13.0
# Name: model_year, Length: 398, dtype: float64

# %%
df['model_year'].rank(method = 'first').head()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# Name: model_year, dtype: float64

# %%
df2
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df2.cumsum()
# Out:
#     a   b   c
# 1   4   7  10
# 2   9  15  21
# 3  15  24  33

# %%
df2.cummax()
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df2.cummin()
# Out:
#    a  b   c
# 1  4  7  10
# 2  4  7  10
# 3  4  7  10

# %%
df2.cumprod()
# Out:
#      a    b     c
# 1    4    7    10
# 2   20   56   110
# 3  120  504  1320

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
s = pd.Series(np.random.randn(1000),
              index = pd.date_range('1/1/2015', periods = 1000),
             columns = ['A','B','C','D'])
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-286-fd4f97abb067> in <module>
#       1 s = pd.Series(np.random.randn(1000),
#       2               index = pd.date_range('1/1/2015', periods = 1000),
# ----> 3              columns = ['A','B','C','D'])
#       4 s
#       5
#
# TypeError: __init__() got an unexpected keyword argument 'columns'

# %%
s = s.cumsum()

# %%
s.plot()

# %%
r = s.rolling(window = 30)
r.mean()
# Out:
# 2015-01-01          NaN
# 2015-01-02          NaN
# 2015-01-03          NaN
# 2015-01-04          NaN
# 2015-01-05          NaN
#                 ...
# 2017-09-22   -39.782441
# 2017-09-23   -39.833187
# 2017-09-24   -39.874625
# 2017-09-25   -39.951346
# 2017-09-26   -40.001541
# Freq: D, Length: 1000, dtype: float64

# %%
s.plot(style = 'k--')
r.mean().plot(style = 'k--')

# %%
df = pd.Series(np.random.randn(1000,4),
              index = pd.date_range('1/1/2015', periods = 1000),
               columns = ['A','B','C','D'])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-282-5355f2782e23> in <module>
#       1 df = pd.Series(np.random.randn(1000,4),
#       2               index = pd.date_range('1/1/2015', periods = 1000),
# ----> 3                columns = ['A','B','C','D'])
#       4 df
#
# TypeError: __init__() got an unexpected keyword argument 'columns'

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
dfe = pd.DataFrame({"B" : [0,1,2,np.nan,4]})
dfe
# Out:
#      B
# 0  0.0
# 1  1.0
# 2  2.0
# 3  NaN
# 4  4.0

# %%
dfe.plot()

# %%
dfe.expanding(2).max().plot()

# %%
import matplotlib as mpl

# %%
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ##kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2015',periods = 1000))
ts.plot()

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2015',periods = 1000),
              columns = list('ABCD'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-305-806ae8cd18b6> in <module>
#       1 df = pd.Series(np.random.randn(1000),
#       2               index=pd.date_range('1/1/2015',periods = 1000),
# ----> 3               columns = list('ABCD'))
#
# TypeError: __init__() got an unexpected keyword argument 'columns'

# %%
df3 = pd.DataFrame(np.random.randn(1000,2),
              columns = ['B','C']).cumsum()
df3.head()
# Out:
#           B         C
# 0  1.096530  0.351769
# 1  0.043816  0.281465
# 2 -0.961367  0.805239
# 3 -0.902062  0.148781
# 4 -2.031037  1.564476

# %%
df3['A'] = pd.Series(list(range(len(df3))))

# %%
df3.head()
# Out:
#           B         C  A
# 0  1.096530  0.351769  0
# 1  0.043816  0.281465  1
# 2 -0.961367  0.805239  2
# 3 -0.902062  0.148781  3
# 4 -2.031037  1.564476  4

# %%
df3.plot(x = 'A', y = 'B')

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
              index=pd.date_range('1/1/2015',periods = 1000),
              columns = list('ABCD'))

# %%
df.head()
# Out:
#                    A         B         C         D
# 2015-01-01 -0.900083  0.827506 -1.461779 -1.666338
# 2015-01-02  0.443527  0.643934 -0.032440  0.431482
# 2015-01-03 -0.350829  0.511443  0.788405 -1.570084
# 2015-01-04  0.536466  0.659598 -0.199692  0.928915
# 2015-01-05 -2.660181 -0.501072  1.346532 -0.744743

# %%
df.tail(2)
# Out:
#                    A         B        C         D
# 2017-09-25  0.733542  0.580174  0.75947  0.409202
# 2017-09-26  0.182079  0.748037 -0.00111  1.071599

# %%
df.iloc[5].plot(kind = 'bar')

# %%
import matplotlib as plt

# %%
df.iloc[5].plot.bar()
plt.axhline(0, color = 'k')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-330-dee4418593f0> in <module>
#       1 df.iloc[5].plot.bar()
# ----> 2 plt.axhline(0, color = 'k')
#
# AttributeError: module 'matplotlib' has no attribute 'axhline'

# %%
df2 = pd.DataFrame(np.random.rand(10,4),
                  columns = ['a','b','c','d'])
df2.head()
# Out:
#           a         b         c         d
# 0  0.993155  0.311213  0.115047  0.901397
# 1  0.885179  0.231083  0.648086  0.800106
# 2  0.747882  0.491452  0.193364  0.699109
# 3  0.829609  0.191763  0.057650  0.485500
# 4  0.394626  0.507314  0.744817  0.001286

# %%
df2.plot.bar(stacked = True)

# %%
df2.plot.bar()

# %%
df2.plot.barh(stacked = True)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df4 = pd.DataFrame({'a' : np.random.randn(1000) + 1,
                   'b' : np.random.randn(1000),
                   'c' : np.random.randn(1000) - 1},
                  columns = ['a','b','c'])

# %%
df4
# Out:
#             a         b         c
# 0    2.513480  0.115320 -1.389789
# 1    2.069250 -0.762519 -1.671823
# 2    1.040019  0.143788 -0.280663
# 3    0.137520 -0.276962  0.205918
# 4    0.704837 -0.448342 -0.240649
# ..        ...       ...       ...
# 995  0.506735  1.504436  1.699299
# 996  3.200147 -1.010406  0.402571
# 997 -0.209077  0.285391 -1.469974
# 998  2.666676 -1.731105 -0.383712
# 999 -0.079381  0.662397 -0.769212
#
# [1000 rows x 3 columns]

# %%
df4.plot.hist(alpha = 0.5)

# %%
df4.plot.hist(stacked = True, bins = 20)

# %%
df4['a'].plot.hist(orientation = 'horizontal', cumulative = True)

# %%
df4['a'].diff().hist()

# %%
df4['a_diff'] = df4['a'].diff()
df4['a_shift'] = df4['a'].shift(1)
df4['a_minus'] = df4['a'] - df4['a_shift']
df4[['a','a_shift','a_diff']]
# Out:
#             a   a_shift    a_diff
# 0    2.513480       NaN       NaN
# 1    2.069250  2.513480 -0.444231
# 2    1.040019  2.069250 -1.029231
# 3    0.137520  1.040019 -0.902499
# 4    0.704837  0.137520  0.567317
# ..        ...       ...       ...
# 995  0.506735  2.226829 -1.720095
# 996  3.200147  0.506735  2.693413
# 997 -0.209077  3.200147 -3.409224
# 998  2.666676 -0.209077  2.875753
# 999 -0.079381  2.666676 -2.746057
#
# [1000 rows x 3 columns]

# %%
df4[['a','b','c']].diff().hist(color = 'k', alpha = 0.5, bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2ea55910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2e5dc190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2e7e8290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2e8afa90>]],
#       dtype=object)

# %%
data = pd.Series(np.random.randn(1000))

# %%
data = pd.DataFrame({'a' : np.random.randn(1000),
                    'b': np.random.randint(0,4,1000)})
data
# Out:
#             a  b
# 0    0.067666  1
# 1    1.198340  2
# 2   -0.345736  1
# 3   -1.216878  0
# 4    0.441563  2
# ..        ... ..
# 995  2.032045  0
# 996  0.078097  2
# 997  0.307393  3
# 998  0.485190  0
# 999 -0.836736  1
#
# [1000 rows x 2 columns]

# %%
data['a'].hist(by = data['b'], figsize = (6,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2b787a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2e41ed10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2e456510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2e48ad10>]],
#       dtype=object)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns = ['A','B','C','D','E'])
df
# Out:
#           A         B         C         D         E
# 0  0.366033  0.892956  0.548539  0.828985  0.854535
# 1  0.607477  0.253140  0.355522  0.713278  0.448896
# 2  0.440139  0.288250  0.108842  0.280597  0.599703
# 3  0.304046  0.762736  0.078897  0.872447  0.314538
# 4  0.331661  0.474117  0.504571  0.501119  0.907979
# 5  0.964637  0.924913  0.049832  0.169812  0.394938
# 6  0.914665  0.887146  0.782999  0.273424  0.287370
# 7  0.491216  0.853272  0.489841  0.358570  0.081707
# 8  0.803611  0.140131  0.714581  0.249063  0.245521
# 9  0.048009  0.333959  0.200409  0.912384  0.783811

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.527149   0.581062   0.383403   0.515968   0.491900
# std     0.293794   0.312070   0.265890   0.288948   0.281851
# min     0.048009   0.140131   0.049832   0.169812   0.081707
# 25%     0.340254   0.299677   0.131734   0.275217   0.294162
# 50%     0.465677   0.618427   0.422681   0.429844   0.421917
# 75%     0.754577   0.878677   0.537547   0.800058   0.737784
# max     0.964637   0.924913   0.782999   0.912384   0.907979

# %%
df.plot.box()

# %%
color = {'boxes' : 'DarkGreen','whiskers' : 'DarkOrange','medians' : 'DarkBlue','caps' : 'Gray'}

# %%
df.plot.box(color = color, sym='r+')

# %%
df.plot.box(vert = False, positions = [1,4,5,6,8])

# %%
df = pd.DataFrame(np.random.rand(10,5))
df
# Out:
#           0         1         2         3         4
# 0  0.014354  0.662255  0.948207  0.881226  0.618398
# 1  0.177552  0.735593  0.144390  0.274597  0.684113
# 2  0.257399  0.980905  0.918952  0.996354  0.851834
# 3  0.263795  0.216219  0.447613  0.856355  0.611188
# 4  0.306045  0.495152  0.531718  0.195929  0.384113
# 5  0.491438  0.513256  0.381401  0.946110  0.302015
# 6  0.603620  0.045403  0.551355  0.555793  0.328816
# 7  0.423168  0.646857  0.240330  0.107600  0.232631
# 8  0.667575  0.621879  0.408655  0.668981  0.207601
# 9  0.374085  0.470097  0.921300  0.145594  0.634563

# %%
bp = df.boxplot()

# %%
df = pd.DataFrame(np.random.rand(10,2), columns = ['Col1','Col2'])
df.head()
# Out:
#        Col1      Col2
# 0  0.104347  0.098151
# 1  0.901582  0.149427
# 2  0.066942  0.342810
# 3  0.160657  0.366414
# 4  0.829105  0.376558

# %%
df['x'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
df.head()
# Out:
#        Col1      Col2  x
# 0  0.104347  0.098151  A
# 1  0.901582  0.149427  A
# 2  0.066942  0.342810  A
# 3  0.160657  0.366414  A
# 4  0.829105  0.376558  A

# %%
bp = df.boxplot(by = 'x')

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50, 2))
df_box['g'] = np.random.choice(['A','B'], size = 50)
df_box.loc[df_box['g'] == 'B', 1] +=3
bp = df_box.boxplot(by = 'g')

# %%
bp = df_box.groupby('g').boxplot()

# %%
df = pd.DataFrame(np.random.rand(10,4),
                 columns = ['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  0.556895  0.084774  0.333002  0.728429
# 1  0.142435  0.552469  0.273043  0.974495
# 2  0.667787  0.255653  0.108311  0.776181
# 3  0.782478  0.761604  0.914403  0.658623
# 4  0.568368  0.201756  0.698296  0.952195

# %%
df.plot.area()

# %%
df.plot()

# %%
df.plot.area(stacked = False, grid = True)

# %%
df.plot(grid = True)

# %%
df = pd.DataFrame(np.random.rand(50, 4),
                 columns = ['a','b','c','d'])
df
# Out:
#            a         b         c         d
# 0   0.753544  0.270584  0.522303  0.098329
# 1   0.713637  0.884041  0.567054  0.994482
# 2   0.178740  0.012200  0.456998  0.931752
# 3   0.846025  0.473330  0.902555  0.225996
# 4   0.304154  0.714994  0.724091  0.018676
# 5   0.285813  0.580486  0.930787  0.338997
# 6   0.120083  0.516273  0.699207  0.298641
# 7   0.861610  0.905807  0.768583  0.261232
# 8   0.938456  0.938642  0.745045  0.910735
# 9   0.237225  0.494967  0.809878  0.954566
# 10  0.637483  0.910850  0.692137  0.042943
# 11  0.833587  0.369949  0.936557  0.483053
# 12  0.125332  0.964454  0.017026  0.676571
# 13  0.140440  0.155313  0.649558  0.981654
# 14  0.694807  0.761974  0.425209  0.138893
# 15  0.216186  0.764700  0.054606  0.490123
# 16  0.180690  0.630925  0.551242  0.567081
# 17  0.818345  0.938987  0.192901  0.712844
# 18  0.697940  0.258296  0.915808  0.532358
# 19  0.557964  0.322772  0.338631  0.332302
# 20  0.978818  0.203215  0.667026  0.574784
# 21  0.051975  0.542838  0.207949  0.091090
# 22  0.869856  0.027370  0.968625  0.327500
# 23  0.410278  0.135544  0.127066  0.413984
# 24  0.617444  0.132267  0.974481  0.180635
# 25  0.760350  0.482162  0.768079  0.302898
# 26  0.015175  0.463369  0.703337  0.066041
# 27  0.669011  0.345479  0.591721  0.229053
# 28  0.267568  0.932827  0.826145  0.145443
# 29  0.647004  0.883951  0.741361  0.515711
# 30  0.135252  0.039884  0.834322  0.117058
# 31  0.523102  0.873058  0.038708  0.692391
# 32  0.476268  0.169264  0.063172  0.032224
# 33  0.242431  0.112707  0.404990  0.042073
# 34  0.926565  0.935263  0.810427  0.188343
# 35  0.587318  0.903511  0.967342  0.067539
# 36  0.317586  0.696863  0.640265  0.632623
# 37  0.828751  0.713110  0.335480  0.167695
# 38  0.764690  0.359315  0.088005  0.729568
# 39  0.881050  0.041264  0.174868  0.420097
# 40  0.340607  0.044769  0.112891  0.438041
# 41  0.071073  0.816245  0.866116  0.131120
# 42  0.193219  0.437493  0.970925  0.773861
# 43  0.131776  0.927180  0.827797  0.392732
# 44  0.140571  0.052136  0.092729  0.886990
# 45  0.168151  0.362887  0.654282  0.604822
# 46  0.394993  0.374605  0.063073  0.428959
# 47  0.719721  0.768031  0.194368  0.862871
# 48  0.028722  0.902129  0.236546  0.128584
# 49  0.317876  0.848761  0.832298  0.345651

# %%
df.plot.scatter(x = 'a', y = 'b', s = 50, grid = True)

# %%
ax = df.plot.scatter(x = 'a', y = 'b', color = 'DarkRed', label = 'Group 1')
df.plot.scatter(x = 'c', y = 'd', color = 'DarkGreen', label = 'Group 2', ax=ax)

# %%
df.plot.scatter(x = 'a', y = 'b', c = 'c', s = 100)

# %%
df.plot.scatter(x = 'a', y = 'b', s = df['c'] * 200)

# %%
df = pd.DataFrame(np.random.randn(1000,2),
                 columns = ['a','b'])
df['b'] = df['b'] + np.arange(1000)
df
# Out:
#             a           b
# 0   -1.179905    0.819041
# 1    0.169362    1.395066
# 2    1.793339    2.620358
# 3    0.687095    3.924752
# 4   -0.953211    4.272744
# ..        ...         ...
# 995 -0.910398  995.028824
# 996  0.359436  994.741707
# 997 -0.162470  995.679853
# 998 -1.030900  996.443378
# 999  1.943475  998.883155
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize = 10)

# %%
df['z'] = np.random.uniform(0,3,1000)
df['z']
# Out:
# 0      0.226877
# 1      1.088080
# 2      0.602748
# 3      2.155595
# 4      2.514195
#          ...
# 995    0.066676
# 996    1.796139
# 997    1.290661
# 998    0.927796
# 999    0.940112
# Name: z, Length: 1000, dtype: float64

# %%
df.plot.hexbin(x = 'a', y = 'b', C = 'z', reduce_C_function = np.max, gridsize = 25)

# %%
series = pd.Series(3*np.random.rand(4),
                  index = ['a','b','c','d'], name = 'series')

# %%
series
# Out:
# a    0.642696
# b    1.334565
# c    2.736501
# d    2.157538
# Name: series, dtype: float64

# %%
series.plot.pie()

# %%
series.plot.pie(labels = ['AA','BB','CC','DD'],
               colors = ['r','g','b','c'],
               autopct = '%.2F',
               fontsize = 20,
               figsize = (6,6))

# %%
df = pd.DataFrame({'mass' : [0.330, 4.87, 5.97],
                  'radius' : [2439.7, 6051.8, 6379.1]},
                 index = ['Mercury','Venus','Earth'])
plot = df.plot.pie(y = 'mass', figsize = (5,5))

# %%
plot = df.plot.pie(subplots = True, figsize = (10, 5))

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000,4),
                 columns = ['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  1.312866 -1.216268  0.101909 -2.081789
# 1  1.145998 -0.077250  0.516622 -0.310701
# 2 -1.116024 -1.326203 -0.036165 -1.240391
# 3 -0.531546 -0.964345  0.404665 -0.643385
# 4 -0.853963 -0.075043 -0.290003  0.162438

# %%
#kde -커널 밀도 함수
scatter_matrix(df, alpha = 0.2, figsize = (6,6), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a30ae4d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30b1c250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30b5ca50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30b97290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a30bc7a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30c052d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30c34f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30c71310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a30c7c310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30cb0c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30d1ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30d5e390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a30d8eb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30dd23d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30e04bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30e47410>]],
#       dtype=object)

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()

# %%
ser.plot.hist()

# %%
ser.plot.density()

# %%
ser.plot.kde()
